# %% [markdown]
# # Install Library

# %%
# Install necessary library
# !pip install langchain-core langgraph>0.2.27
# !pip install -qU langchain-openai
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.7/50.7 kB 2.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 411.5/411.5 kB 9.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 31.0 MB/s eta 0:00:00

# %% [markdown]
# # Import Library

# %%
# Utilization
import os
from rich.panel import Panel
from rich.syntax import Syntax
from rich.console import Console
from google.colab import userdata
from IPython.display import Image, display
from typing_extensions import Annotated, TypedDict
from typing import Sequence, Literal, Optional, Dict, Any
# LangChain
from langchain_openai import AzureChatOpenAI
from langchain_core.messages import AIMessage
from langchain_core.messages import BaseMessage
from langchain_core.messages import HumanMessage
from langchain_core.output_parsers import StrOutputParser
from langchain_core.messages import SystemMessage, trim_messages
from langchain_core.language_models.chat_models import BaseChatModel
from langchain.callbacks.tracers.langchain import wait_for_all_tracers
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder
# LangGraph
from langgraph.types import Command
from langgraph.graph.message import add_messages
from langgraph.prebuilt import create_react_agent
from langgraph.checkpoint.memory import MemorySaver
from langgraph.graph import START, END, MessagesState, StateGraph
# LangSmith
from langsmith import Client

# %% [markdown]
# # How to set up key in colab
# If you use colab you can use private key of google, on the left side of navigation bar, I can see a key -> just simple set key is name and next blank is value \
# Function: `userdata("KEY_NAME")`
#
# # How to set up key in local
# you can create file .env and use load_dotenv() to load environment file \
# Function: `load_dotenv()`

# %% [markdown]
# # LangSmith Setup

# %%
# Extract from private key for LangSmith
os.environ["LANGCHAIN_TRACING_V2"] = "true"
os.environ["LANGCHAIN_API_KEY"] = userdata.get('LANGCHAIN_API_KEY')
os.environ["LANGCHAIN_PROJECT"] = userdata.get('LANGCHAIN_PROJECT')
os.environ["LANGCHAIN_ENDPOINT"] = userdata.get('LANGCHAIN_ENDPOINT')
client = Client()

# %% [markdown]
# # LLMs Connection

# %%
# Extract from private key for Azure OpenAI
os.environ["AZURE_OPENAI_API_KEY"] = userdata.get('AZURE_OPENAI_API_KEY')
os.environ["AZURE_OPENAI_ENDPOINT"] = userdata.get('AZURE_OPENAI_ENDPOINT')
os.environ["AZURE_OPENAI_API_VERSION"] = userdata.get('AZURE_OPENAI_API_VERSION')
os.environ["AZURE_OPENAI_DEPLOYMENT_NAME"] = userdata.get('AZURE_OPENAI_DEPLOYMENT_NAME')

# Connect Azure OpenAI
# you can change type of model in langchain website: https://python.langchain.com/docs/tutorials/chatbot/
model = AzureChatOpenAI(
    azure_endpoint=os.environ["AZURE_OPENAI_ENDPOINT"],
    azure_deployment=os.environ["AZURE_OPENAI_DEPLOYMENT_NAME"],
    openai_api_version=os.environ["AZURE_OPENAI_API_VERSION"],
    model_name=os.environ["AZURE_OPENAI_DEPLOYMENT_NAME"],
)

# %% [markdown]
# # Define template for system prompt

# %%
# Define System prompt instruction for sales
# example for you, you can change it
def system_prompt_instructions_sales() -> str:
    return (
'''
# **Role Description:**

- You are a professional copywriter and sales strategist with expertise in creating captivating livestream sales scripts tailored to diverse product categories and brands.
- Your task is to develop a comprehensive, engaging script for a livestream sales session on e-commerce platforms, specifically for [Brand Name], a premium [Product Type] brand.
- Craft a narrative that not only showcases the product's unique value but also creates an emotional connection with the audience, ultimately driving viewer engagement and sales conversions.
- Leverage storytelling techniques, cultural insights, and strategic communication to transform viewers into potential customers.
.... More
'''
)

# %% [markdown]
# # Chatbot with multi-user and multi-session

# %%
# Create config
# if you want to many users has history for them
# each user has many sessions
config = {"configurable": {"user_id": "123", "thread_id": "abc123"}}

# Define Template
prompt_template = ChatPromptTemplate.from_messages(
    [
        (
            "system",
            system_prompt_instructions_sales(),
        ),
        MessagesPlaceholder(variable_name="messages"),
    ]
)

# %%
# Sample Workflow
def call_model(state: MessagesState):
    prompt = prompt_template.invoke(state)
    response = model.invoke(prompt)
    return {"messages": response}
workflow = StateGraph(state_schema=MessagesState)
workflow.add_edge(START, "model")
workflow.add_node("model", call_model)

# Chat history
memory = MemorySaver()
app = workflow.compile(checkpointer=memory)

# %%
# promot the first time
# Example
query = '''
Hãy viết kịch bản với sản phẩm dưới đây, độ dài mỗi mục tối thiểu từ 300 đến 400 chữ. Đây là thông tin sản phẩm:

Sản phẩm 1:

Tên sản phẩm: Nước tăng lực Pepsi
'''

input_messages = [HumanMessage(query)]
output = app.invoke({"messages": input_messages}, config)
print(output["messages"][-1])
output["messages"][-1].pretty_print()
# Out:
# content='## **Tên sản phẩm**: Nước tăng lực Pepsi\n\n### **Mở đầu sản phẩm hoặc chuyển tiếp sản phẩm khác**:\n"Các anh chị em ơi, hôm nay chúng ta đã trải qua rất nhiều sản phẩm tuyệt vời, nhưng giờ em muốn giới thiệu đến mọi người một sản phẩm không thể thiếu trong cuộc sống hàng ngày của chúng ta, đó chính là Nước tăng lực Pepsi! Nước tăng lực này không chỉ cung cấp năng lượng mà còn giúp chúng ta tỉnh táo hơn trong những giờ phút căng thẳng. Hãy cùng em khám phá điều gì đặc biệt ở sản phẩm này nhé!"\n\n### **Giới thiệu sản phẩm**:\n"Nước tăng lực Pepsi là một sản phẩm tuyệt vời dành cho tất cả mọi người từ trẻ em trên 1 tuổi cho đến người lớn. Trong cuộc sống bận rộn hiện đại, đôi khi chúng ta cần một chút hỗ trợ để giữ cho cơ thể hoạt động hiệu quả và đầy năng lượng. Nước tăng lực Pepsi ra đời để đáp ứng nhu cầu đó. Với mỗi ngụm nước, bạn sẽ cảm nhận được sự tươi mới và sức mạnh tràn đầy. Hãy tưởng tượng bạn đang làm việc chăm chỉ hay tham gia một hoạt động thể thao và chỉ cần một lon Nước tăng lực Pepsi, bạn sẽ thấy mình hồi phục sức lực ngay lập tức, tinh thần phấn chấn hơn và sẵn sàng cho những thử thách tiếp theo. Đó chính là giá trị mà sản phẩm này mang lại cho bạn! Hãy để Nước tăng lực Pepsi giúp bạn tiếp thêm sức mạnh cho những phút giây quan trọng trong cuộc sống."\n\n### **Giữ chân người xem**:\n"Như các anh chị em đã thấy, Nước tăng lực Pepsi không chỉ đơn thuần là một loại nước giải khát. Nó là nguồn động lực cho những ai đang tìm kiếm sự tỉnh táo và năng lượng. Em muốn hỏi mọi người, trong những lúc cần tập trung hay làm việc căng thẳng, anh chị thường làm gì để tỉnh táo hơn? Hãy chia sẻ với em nhé! Và đừng quên, nếu anh chị đang tìm kiếm một sản phẩm có thể giúp mình vượt qua những giờ làm việc dài, thì Nước tăng lực Pepsi chính là lựa chọn hoàn hảo. Hãy để lại phản hồi hoặc câu hỏi cho em, em sẽ luôn sẵn sàng trả lời và chia sẻ thêm!"\n\n### **Đặc điểm sản phẩm**:\n"Nước tăng lực Pepsi mang đến nhiều lợi ích nổi bật cho sức khỏe và tinh thần của bạn. Trước hết, sản phẩm này giúp tăng cường sự tỉnh táo, giúp bạn cảm thấy năng động và sẵn sàng đối mặt với mọi thử thách trong ngày. Không chỉ vậy, sản phẩm còn có hương vị thơm ngon, dễ uống, khiến cho bạn cảm thấy thích thú mỗi khi thưởng thức. Hãy tưởng tượng một buổi chiều hè oi ả, bạn thưởng thức một lon Nước tăng lực Pepsi, không khí mát lạnh và vị ngọt dịu nhẹ giúp bạn xua tan mọi căng thẳng. Điều này thật tuyệt phải không nào? Hãy trải nghiệm ngay cảm giác này với Nước tăng lực Pepsi!"\n\n### **Tính năng nổi bật**:\n"Điểm nổi bật nhất của Nước tăng lực Pepsi chính là khả năng giúp bạn tỉnh táo và tập trung hơn. Với những người làm việc văn phòng, sinh viên hay thậm chí là những vận động viên, sản phẩm này sẽ là người bạn đồng hành không thể thiếu. Điều đặc biệt là, Nước tăng lực Pepsi không chỉ cung cấp năng lượng tức thì mà còn giúp bạn duy trì sự tỉnh táo trong thời gian dài. Hãy thử một lon và cảm nhận sự khác biệt nhé! Với những người đang tìm kiếm sự khôi phục sức lực sau một ngày dài, chắc chắn Nước tăng lực Pepsi sẽ không làm bạn thất vọng."\n\n### **Giá niêm yết và giá giảm trong phiên live**:\n"Giá niêm yết cho Nước tăng lực Pepsi là rất hợp lý. Một lon đơn chỉ có giá 45k, trong khi lốc 6 lon có giá 235k và khay 10 lon là 450k. Tuy nhiên, trong phiên livestream hôm nay, chúng em có một ưu đãi vô cùng hấp dẫn: bạn sẽ nhận được deal 8 tặng 2 với giá chỉ 360k cho khay 10 lon! Đây thực sự là một cơ hội tuyệt vời để mọi người có thể tích trữ Nước tăng lực Pepsi cho những lúc cần thiết. Hãy nhanh tay đặt hàng vì số lượng có hạn, và tận hưởng sự tỉnh táo mà sản phẩm mang lại nhé!"\n\n### **Kêu gọi mua hàng**:\n"Các anh chị em ơi, đừng bỏ lỡ cơ hội này nhé! Hãy nhấn vào link dưới video để đặt hàng ngay Nước tăng lực Pepsi với ưu đãi cực hấp dẫn. Em cam đoan rằng, sản phẩm này sẽ không chỉ làm bạn hài lòng mà còn giúp bạn duy trì sức khỏe và sự tỉnh táo trong mọi tình huống. Hãy để lại câu hỏi hoặc phản hồi về sản phẩm, em rất muốn nghe ý kiến của mọi người ...
# ================================== Ai Message ==================================
#
# ## **Tên sản phẩm**: Nước tăng lực Pepsi
#
# ### **Mở đầu sản phẩm hoặc chuyển tiếp sản phẩm khác**:
# "Các anh chị em ơi, hôm nay chúng ta đã trải qua rất nhiều sản phẩm tuyệt vời, nhưng giờ em muốn giới thiệu đến mọi người một sản phẩm không thể thiếu trong cuộc sống hàng ngày của chúng ta, đó chính là Nước tăng lực Pepsi! Nước tăng lực này không chỉ cung cấp năng lượng mà còn giúp chúng ta tỉnh táo hơn trong những giờ phút căng thẳng. Hãy cùng em khám phá điều gì đặc biệt ở sản phẩm này nhé!"
#
# ### **Giới thiệu sản phẩm**:
# "Nước tăng lực Pepsi là một sản phẩm tuyệt vời dành cho tất cả mọi người từ trẻ em trên 1 tuổi cho đến người lớn. Trong cuộc sống bận rộn hiện đại, đôi khi chúng ta cần một chút hỗ trợ để giữ cho cơ thể hoạt động hiệu quả và đầy năng lượng. Nước tăng lực Pepsi ra đời để đáp ứng nhu cầu đó. Với mỗi ngụm nước, bạn sẽ cảm nhận được sự tươi mới và sức mạnh tràn đầy. Hãy tưởng tượng bạn đang làm việc chăm chỉ hay tham gia một hoạt động thể thao và chỉ cần một lon Nước tăng lực Pepsi, bạn sẽ thấy mình hồi phục sức lực ngay lập tức, tinh thần phấn chấn hơn và sẵn sàng cho những thử thách tiếp theo. Đó chính là giá trị mà sản phẩm này mang lại cho bạn! Hãy để Nước tăng lực Pepsi giúp bạn tiếp thêm sức mạnh cho những phút giây quan trọng trong cuộc sống."
#
# ### **Giữ chân người xem**:
# "Như các anh chị em đã thấy, Nước tăng lực Pepsi không chỉ đơn thuần là một loại nước giải khát. Nó là nguồn động lực cho những ai đang tìm kiếm sự tỉnh táo và năng lượng. Em muốn hỏi mọi người, trong những lúc cần tập trung hay làm việc căng thẳng, anh chị thường làm gì để tỉnh táo hơn? Hãy chia sẻ với em nhé! Và đừng quên, nếu anh chị đang tìm kiếm một sản phẩm có thể giúp mình vượt qua những giờ làm việc dài, thì Nước tăng lực Pepsi chính là lựa chọn hoàn hảo. Hãy để lại phản hồi hoặc câu hỏi cho em, em sẽ luôn sẵn sàng trả lời và chia sẻ thêm!"
#
# ### **Đặc điểm sản phẩm**:
# "Nước tăng lực Pepsi mang đến nhiều lợi ích nổi bật cho sức khỏe và tinh thần của bạn. Trước hết, sản phẩm này giúp tăng cường sự tỉnh táo, giúp bạn cảm thấy năng động và sẵn sàng đối mặt với mọi thử thách trong ngày. Không chỉ vậy, sản phẩm còn có hương vị thơm ngon, dễ uống, khiến cho bạn cảm thấy thích thú mỗi khi thưởng thức. Hãy tưởng tượng một buổi chiều hè oi ả, bạn thưởng thức một lon Nước tăng lực Pepsi, không khí mát lạnh và vị ngọt dịu nhẹ giúp bạn xua tan mọi căng thẳng. Điều này thật tuyệt phải không nào? Hãy trải nghiệm ngay cảm giác này với Nước tăng lực Pepsi!"
#
# ### **Tính năng nổi bật**:
# "Điểm nổi bật nhất của Nước tăng lực Pepsi chính là khả năng giúp bạn tỉnh táo và tập trung hơn. Với những người làm việc văn phòng, sinh viên hay thậm chí là những vận động viên, sản phẩm này sẽ là người bạn đồng hành không thể thiếu. Điều đặc biệt là, Nước tăng lực Pepsi không chỉ cung cấp năng lượng tức thì mà còn giúp bạn duy trì sự tỉnh táo trong thời gian dài. Hãy thử một lon và cảm nhận sự khác biệt nhé! Với những người đang tìm kiếm sự khôi phục sức lực sau một ngày dài, chắc chắn Nước tăng lực Pepsi sẽ không làm bạn thất vọng."
#
# ### **Giá niêm yết và giá giảm trong phiên live**:
# "Giá niêm yết cho Nước tăng lực Pepsi là rất hợp lý. Một lon đơn chỉ có giá 45k, trong khi lốc 6 lon có giá 235k và khay 10 lon là 450k. Tuy nhiên, trong phiên livestream hôm nay, chúng em có một ưu đãi vô cùng hấp dẫn: bạn sẽ nhận được deal 8 tặng 2 với giá chỉ 360k cho khay 10 lon! Đây thực sự là một cơ hội tuyệt vời để mọi người có thể tích trữ Nước tăng lực Pepsi cho những lúc cần thiết. Hãy nhanh tay đặt hàng vì số lượng có hạn, và tận hưởng sự tỉnh táo mà sản phẩm mang lại nhé!"
#
# ### **Kêu gọi mua hàng**:
# "Các anh chị em ơi, đừng bỏ lỡ cơ hội này nhé! Hãy nhấn vào link dưới video để đặt hàng ngay Nước tăng lực Pepsi với ưu đãi cực hấp dẫn. Em cam đoan rằng, sản phẩm này sẽ không chỉ làm bạn hài lòng mà còn giúp bạn duy trì sức khỏe và sự tỉnh táo trong mọi tình huống. Hãy để lại câu hỏi hoặc phản hồi về sản phẩm, em rất muốn nghe ý kiến của mọi người!"
#
# ### **Làm nổi bật ưu điểm bán hàng của sản phẩm**:
# "Nước tăng lực Pepsi không chỉ là một thức uống, mà còn là một nguồn năng lượng dồi dào cho cuộc sống hàng ngày của bạn. Với hương vị thơm ngon và khả năng giúp bạn tỉnh táo, sản phẩm này thật sự xứng đáng có mặt trong tủ lạnh của mỗi gia đình. Hãy nhớ rằng, sự tỉnh táo và khỏe mạnh là chìa khóa để bạn đạt được thành công trong công việc cũng như cuộc sống. Nước tăng lực Pepsi sẽ là người bạn đồng hành tuyệt vời để bạn vượt qua mọi thử thách!"
#
# ### **Gợi nhớ đặc điểm sản phẩm**:
# "Để mọi người dễ dàng nhớ lại, Nước tăng lực Pepsi có những điểm nổi bật như: giúp tăng cường sự tỉnh táo, hương vị thơm ngon, và là lựa chọn hoàn hảo cho mọi lứa tuổi từ trẻ em trên 1 tuổi đến người lớn. Hãy luôn ghi nhớ rằng, sản phẩm này không chỉ là nước giải khát, mà còn là nguồn năng lượng thiết yếu cho cuộc sống của bạn!"
#
# ### **Kêu gọi mua hàng**:
# "Vậy còn chần chờ gì nữa? Hãy nhanh tay đặt hàng Nước tăng lực Pepsi ngay bây giờ để không bỏ lỡ ưu đãi đặc biệt trong hôm nay. Chỉ với 360k cho deal 8 tặng 2 khay 10 lon, bạn đã có thể tích trữ được nguồn năng lượng tuyệt vời này cho những ngày dài làm việc hay học tập. Hãy nhấn vào link và trải nghiệm sự tỉnh táo mà sản phẩm mang lại!"
#
# ### **Sản phẩm dành cho ai và không dành cho ai**:
# "Nước tăng lực Pepsi phù hợp với mọi lứa tuổi từ trẻ em trên 1 tuổi cho đến người lớn. Tuy nhiên, sản phẩm này không dành cho những ai nhạy cảm với caffeine hoặc có vấn đề về sức khỏe liên quan đến tiêu thụ đồ uống có ga. Nếu bạn đang tìm kiếm một giải pháp tăng cường năng lượng cho bản thân, Nước tăng lực Pepsi chính là lựa chọn hoàn hảo!"
#
# ### **Thúc đẩy người xem mua hàng**:
# "Các anh chị em ơi, hãy để Nước tăng lực Pepsi trở thành người bạn đồng hành trong cuộc sống của bạn! Với những lợi ích tuyệt vời mà sản phẩm mang lại, em tin chắc bạn sẽ không hối tiếc khi trải nghiệm. Hãy đặt hàng ngay hôm nay để tận hưởng sự tỉnh táo và sức mạnh mà sản phẩm này mang lại cho bạn!"
#
# ### **Cam kết dịch vụ**:
# "Cuối cùng, em muốn nhắc nhở mọi người về cam kết dịch vụ của chúng em. Tất cả sản phẩm đều được đảm bảo chất lượng và sẽ đến tay bạn nhanh chóng nhất có thể. Nếu có bất kỳ vấn đề gì về sản phẩm, chúng em luôn sẵn sàng hỗ trợ và chấp nhận đổi trả theo chính sách của cửa hàng. Hãy yên tâm khi mua sắm cùng chúng em nhé!"

# %%
# Enhance performance

query = "Viết lại văn bản theo văn phong vui vẻ"

input_messages = [HumanMessage(query)]
output = app.invoke({"messages": input_messages}, config)
output["messages"][-1].pretty_print()
# Out:
# ================================== Ai Message ==================================
#
# ## **Tên sản phẩm**: Laptop Siêu Mạnh
#
# ### **Mở đầu sản phẩm hoặc chuyển tiếp sản phẩm khác**:
# Chào mừng cả nhà đến với livestream hôm nay! Hôm nay, chúng ta sẽ cùng nhau khám phá một sản phẩm cực kỳ thú vị và không thể thiếu trong cuộc sống hiện đại - đó chính là Laptop Siêu Mạnh! Nếu bạn đang tìm kiếm một người bạn đồng hành đáng tin cậy cho công việc, học tập hoặc giải trí, thì đây chính là lựa chọn hoàn hảo dành cho bạn đấy!
#
# ### **Giới thiệu sản phẩm**:
# Laptop Siêu Mạnh không chỉ đơn thuần là một chiếc máy tính, mà còn là một công cụ hỗ trợ tuyệt vời giúp bạn thực hiện mọi ý tưởng và dự án của mình. Với thiết kế tinh tế và hiệu suất ấn tượng, sản phẩm này sẽ khiến bạn cảm thấy như đang sở hữu một siêu anh hùng trong tay! Hãy thử tưởng tượng xem, bạn có thể hoàn thành công việc một cách nhanh chóng, hay thậm chí là chơi game thỏa thích mà không lo lag một tí nào. Điều đó thật tuyệt vời phải không nào?
#
# ### **Giữ chân người xem**:
# Em rất muốn biết, cả nhà mình có ai đang tìm kiếm một chiếc laptop mới không? Nếu có thì hãy cho em biết lý do mà anh chị muốn đổi máy nhé! Chắc chắn rằng Laptop Siêu Mạnh sẽ không làm bạn thất vọng đâu. Hãy cùng chờ xem những điều tuyệt vời mà sản phẩm này mang lại nhé!
#
# ### **Đặc điểm sản phẩm**:
# Laptop Siêu Mạnh được trang bị bộ vi xử lý hiện đại, RAM khủng và ổ cứng SSD, điều này đồng nghĩa với việc bạn có thể chạy nhiều ứng dụng cùng lúc mà không lo bị đứng máy. Ngoài ra, màn hình sắc nét sẽ giúp bạn thưởng thức những bộ phim yêu thích hay làm việc một cách thoải mái nhất. Bạn có thể dễ dàng mang theo bên mình nhờ vào thiết kế mỏng nhẹ, rất thích hợp cho những ai thường xuyên di chuyển.
#
# ### **Tính năng nổi bật**:
# Một trong những tính năng nổi bật của Laptop Siêu Mạnh chính là khả năng xử lý đa nhiệm siêu việt. Bạn có thể mở hàng loạt tab, làm việc trên nhiều phần mềm cùng một lúc mà không gặp bất kỳ trở ngại nào. Thêm vào đó, khả năng kết nối nhanh chóng và ổn định sẽ giúp bạn dễ dàng truy cập internet và làm việc từ xa. Thật tuyệt vời phải không nào?
#
# ### **Giá niêm yết và giá giảm trong phiên live**:
# Với mức giá niêm yết cực kỳ hợp lý, Laptop Siêu Mạnh chỉ có giá 15 triệu đồng. Nhưng trong phiên livestream ngày hôm nay, chúng tôi đang có chương trình khuyến mãi đặc biệt, chỉ với 12 triệu đồng thôi! Đúng vậy, bạn có thể sở hữu một chiếc laptop mạnh mẽ với mức giá siêu ưu đãi. Hãy nhanh tay đặt hàng ngay nhé!
#
# ### **Kêu gọi mua hàng**:
# Cả nhà ơi, đừng bỏ lỡ cơ hội này nhé! Hãy nhấn vào link bên dưới để đặt hàng ngay Laptop Siêu Mạnh với giá cực kỳ hấp dẫn. Cơ hội như thế này không có nhiều đâu, nên hãy nhanh tay lên nào!
#
# ### **Làm nổi bật ưu điểm bán hàng của sản phẩm**:
# Tại sao bạn nên chọn Laptop Siêu Mạnh? Bởi vì nó không chỉ đáp ứng mọi nhu cầu công việc mà còn mang lại trải nghiệm tuyệt vời trong giải trí. Với sản phẩm này, bạn sẽ cảm thấy tự tin hơn khi làm việc và thư giãn. Hãy để Laptop Siêu Mạnh trở thành người bạn đồng hành đáng tin cậy trong mọi hoạt động của bạn nhé!
#
# ### **Gợi nhớ đặc điểm sản phẩm**:
# Nhắc lại một chút về những điều tuyệt vời của Laptop Siêu Mạnh: hiệu suất mạnh mẽ, thiết kế mỏng nhẹ, khả năng xử lý đa nhiệm siêu việt và một mức giá không thể tốt hơn trong phiên livestream này! Hãy để sản phẩm này đồng hành cùng bạn trong mọi thử thách cuộc sống nhé!
#
# ### **Kêu gọi mua hàng**:
# Cuối cùng, em xin nhắc lại rằng hãy nhanh tay đặt hàng Laptop Siêu Mạnh ngay hôm nay để không bỏ lỡ cơ hội có một không hai này. Hãy nhấn vào link để trở thành chủ nhân của chiếc laptop tuyệt vời này nhé!
#
# ### **Sản phẩm dành cho ai và không dành cho ai**:
# Laptop Siêu Mạnh phù hợp cho mọi đối tượng từ học sinh, sinh viên đến người đi làm. Tuy nhiên, nếu bạn chỉ cần một chiếc máy tính để lướt web hay xem phim thì có thể sản phẩm này sẽ hơi thừa một chút. Hãy cân nhắc kỹ lưỡng trước khi quyết định nhé!
#
# ### **Thúc đẩy người xem mua hàng**:
# Hãy để Laptop Siêu Mạnh trở thành người bạn đồng hành đáng tin cậy của bạn trong công việc và giải trí. Chỉ cần một cú nhấp chuột, bạn sẽ có ngay sản phẩm tuyệt vời này trong tay. Đừng chần chừ nữa, hãy hành động ngay để không bỏ lỡ cơ hội sở hữu chiếc laptop tuyệt vời này nhé!
#
# ### **Cam kết dịch vụ**:
# Chúng tôi cam kết mang đến cho bạn sản phẩm chất lượng nhất cùng với dịch vụ khách hàng tận tâm. Nếu có bất kỳ vấn đề gì về sản phẩm, chúng tôi luôn sẵn sàng hỗ trợ bạn trong việc đổi trả hoặc hoàn tiền theo chính sách của chúng tôi. Hãy yên tâm khi đặt hàng Laptop Siêu Mạnh ngay hôm nay!

# %%
# Pre-format for output
class PrettyChatbot:
    def __init__(self, model: BaseChatModel, config):
        """
        Initialize the chatbot with a configurable language model.

        :param model: The specific Claude model to use
        """
        # Initialize console for pretty printing
        self.console = Console()

        # Set up the chat model
        self.chat_model = model
        self.config = config

    def display_welcome_banner(self):
        """Display an attractive welcome banner for the chatbot."""
        welcome_text = Panel.fit(
            "[bold cyan]Welcome to PrettyChatbot[/bold cyan]\n"
            "[green]Type 'FINISH' to exit[/green]",
            border_style="bold blue"
        )
        self.console.print(welcome_text)

    def get_user_input(self) -> str:
        """
        Prompt for and return user input with rich formatting.

        :return: User's input query
        """
        return self.console.input(
            Panel(
                "[bold green]Enter your query:[/bold green]",
                border_style="green"
            )
        )

    def process_query(self, query: str) -> str:
        """
        Process the user's query and return the AI's response.

        :param query: User's input query
        :return: AI's response
        """
        try:
            # Create message input
            input_messages = [HumanMessage(content=query)]

            # Invoke the chat model
            response = self.chat_model.invoke({"messages": input_messages}, self.config)
            return response["messages"][-1].content
        except Exception as e:
            return f"[Error] {str(e)}"

    def display_response(self, response: str):
        """
        Display the AI's response with rich formatting.

        :param response: AI's response text
        """
        response_panel = Panel(
            response,
            title="[bold blue]Chatbot Response[/bold blue]",
            border_style="cyan"
        )
        self.console.print(response_panel)

# %%
# Chatbot
class Chatbot:
    def __init__(self, model: BaseChatModel, config: Dict):
        # simple model
        self.model = model
        # advanced model
        self.config = config
        self.main_model = self.workflow()
        self.chat_console_instance = PrettyChatbot(self.main_model, self.config)

    def _call_model(self, state: MessagesState):
        prompt_template = ChatPromptTemplate.from_messages(
        [
            (
                "system",
                system_prompt_instructions_sales(),
            ),
            MessagesPlaceholder(variable_name="messages"),
        ]
        )
        prompt = prompt_template.invoke(state)
        response = self.model.invoke(prompt)
        return {"messages": response}

    def workflow(self):
        # Define workflow
        workflow = StateGraph(state_schema=MessagesState)
        workflow.add_edge(START, "model")
        workflow.add_node("model", self._call_model)

        # Chat history
        memory = MemorySaver()
        main_model = workflow.compile(checkpointer=memory)
        return main_model

    def prompt_first_product(self):
        prompt = 'Hãy viết kịch bản với sản phẩm dưới đây, độ dài mỗi mục tối thiểu từ 300 đến 400 chữ. Đây là thông tin sản phẩm:'
        first_product = '''
        Sản phẩm 1:

        Tên sản phẩm: Nước tăng lực Pepsi
        '''
        return prompt + first_product

    def sample_first_product(self):
        input_messages = [HumanMessage(self.prompt_first_product())]
        output = self.main_model.invoke({"messages": input_messages}, self.config)
        return output["messages"][-1].content


    def chat_console_run(self):
        self.chat_console_instance.display_welcome_banner()
        self.chat_console_instance.display_response(self.sample_first_product())
        while True:
            # Get user input
            user_input = self.chat_console_instance.get_user_input()

            # Check for exit condition
            if user_input.upper() == "FINISH":
                break

            # Process query and get response
            response = self.chat_console_instance.process_query(user_input)

            # Display response
            self.chat_console_instance.display_response(response)

        # Farewell message
        goodbye_panel = Panel.fit(
            "[bold magenta]Thank you for chatting! Goodbye.[/bold magenta]",
            border_style="bold red"
        )
        self.chat_console_instance.console.print(goodbye_panel)

# %%
config = {"configurable": {"user_id": "124", "thread_id": "abc124"}}
chat = Chatbot(model, config)
chat.chat_console_run()
# Out:
# ╭──────────────────────────╮
# │ Welcome to PrettyChatbot │
# │ Type 'FINISH' to exit    │
# ╰──────────────────────────╯
# ╭─────────────────────────────────────────────── Chatbot Response ────────────────────────────────────────────────╮
# │ ## **Tên sản phẩm**: Nước tăng lực Pepsi                                                                        │
# │                                                                                                                 │
# │ ---                                                                                                             │
# │                                                                                                                 │
# │ ## **Mở đầu sản phẩm hoặc chuyển tiếp sản phẩm khác**:                                                          │
# │                                                                                                                 │
# │ "Cả nhà mình ơi, hôm nay em muốn chia sẻ với mọi người một sản phẩm tuyệt vời mà chắc chắn sẽ giúp chúng ta     │
# │ thêm năng lượng và sự tỉnh táo trong những ngày bận rộn này. Đó chính là Nước tăng lực Pepsi! Không chỉ là một  │
# │ món đồ uống thông thường, mà đây là một nguồn sức mạnh giúp chúng ta vượt qua mọi thử thách. Hãy cùng em khám   │
# │ phá sản phẩm này nhé!"                                                                                          │
# │                                                                                                                 │
# │ ---                                                                                                             │
# │                                                                                                                 │
# │ ## **Giới thiệu sản phẩm**:                                                                                     │
# │                                                                                                                 │
# │ "Nước tăng lực Pepsi không chỉ đơn thuần là một thức uống mà nó là một bước tiến trong việc cung cấp năng lượng │
# │ cho cả gia đình mình. Được thiết kế đặc biệt để tiếp thêm sức mạnh và giúp chúng ta luôn tỉnh táo, sản phẩm này │
# │ hoàn toàn phù hợp cho mọi lứa tuổi, từ trẻ em trên 1 tuổi cho đến người lớn. Trong một thế giới đầy căng thẳng  │
# │ và áp lực, việc tìm kiếm một nguồn năng lượng nhanh chóng là điều rất cần thiết. Chính vì vậy, Nước tăng lực    │
# │ Pepsi ra đời như một giải pháp tuyệt vời. Hãy thử tưởng tượng bạn đang làm việc hay học tập, và đột nhiên cảm   │
# │ thấy mệt mỏi, không thể tập trung. Lúc này, một lon Nước tăng lực Pepsi sẽ giúp bạn tỉnh táo và tràn đầy năng   │
# │ lượng, giúp bạn hoàn thành công việc một cách xuất sắc."                                                        │
# │                                                                                                                 │
# │ ---                                                                                                             │
# │                                                                                                                 │
# │ ## **Giữ chân người xem**:                                                                                      │
# │                                                                                                                 │
# │ "Các anh chị em có bao giờ cảm thấy mệt mỏi giữa giờ học hay giờ làm không? Em chắc chắn rằng ai trong chúng ta │
# │ cũng đã từng trải qua cảm giác đó. Vậy tại sao không thử ngay Nước tăng lực Pepsi để giúp mình tỉnh táo hơn?    │
# │ Hãy chia sẻ với em trong chat nhé, mọi người thường làm gì để lấy lại năng lượng trong những lúc như vậy? Đừng  │
# │ ngần ngại, em rất muốn nghe ý kiến của cả nhà mình!"                                                            │
# │                                                                                                                 │
# │ ---                                                                                                             │
# │                                                                                                                 │
# │ ## **Đặc điểm sản phẩm**:                                                                                       │
# │                                                                                                                 │
# │ "Nước tăng lực Pepsi có những đặc điểm nổi bật mà em muốn nhấn mạnh. Đầu tiên, sản phẩm này giúp tăng cường sự  │
# │ tỉnh táo, giúp chúng ta tập trung hơn vào công việc và học tập. Không chỉ vậy, với hương vị thơm ngon, mỗi sip  │
# │ nước uống không chỉ mang lại sự tỉnh táo mà còn là một trải nghiệm thú vị cho vị giác. Đặc biệt, nước tăng lực  │
# │ này có thể sử dụng trong nhiều trường hợp khác nhau: khi bạn cần tỉnh táo để lái xe, trong những buổi họp căng  │
# │ thẳng hay thậm chí trong những buổi tiệc tùng với bạn bè.                                                       │
# │                                                                                                                 │
# │ Thêm vào đó, Nước tăng lực Pepsi rất dễ dàng để mang theo bên mình. Bạn có thể chọn mua lốc 6 lon hoặc khay 10  │
# │ lon, tiện lợi để chia sẻ với bạn bè và gia đình. Đó là lý do tại sao Pepsi không chỉ đơn thuần là một đồ uống,  │
# │ mà là một phần không thể thiếu trong cuộc sống hàng ngày của chúng ta."                                         │
# │                                                                                                                 │
# │ ---                                                                                                             │
# │                                                                                                                 │
# │ ## **Tính năng nổi bật**:                                                                                       │
# │                                                                                                                 │
# │ "Không thể không nhắc đến tính năng nổi bật của Nước tăng lực Pepsi - đó chính là khả năng tăng cường sự tỉnh   │
# │ táo. Sản phẩm này đã được nghiên cứu và phát triển để cung cấp năng lượng nhanh chóng, giúp bạn luôn trong      │
# │ trạng thái sẵn sàng cho mọi thử thách. Hãy nghĩ đến những lúc bạn cần phải hoàn thành công việc gấp rút hoặc    │
# │ chuẩn bị cho một buổi thi quan trọng - một lon Nước tăng lực Pepsi sẽ là người bạn đồng hành tuyệt vời, giúp    │
# │ bạn vượt qua mọi rào cản. Với sự kết hợp hoàn hảo giữa hương vị và công dụng, chắc chắn bạn sẽ không muốn bỏ    │
# │ lỡ!"                                                                                                            │
# │                                                                                                                 │
# │ ---                                                                                                             │
# │                                                                                                                 │
# │ ## **Giá niêm yết và giá giảm trong phiên live**:                                                               │
# │                                                                                                                 │
# │ "Hãy cùng em xem qua mức giá của sản phẩm tuyệt vời này nhé! Giá niêm yết của Nước tăng lực Pepsi là 45k cho    │
# │ một lon đơn, 235k cho lốc 6 lon, và 450k cho khay 10 lon. Nhưng đừng quên, trong phiên livestream hôm nay,      │
# │ chúng ta có một deal cực kỳ hấp dẫn: chỉ với 360k, bạn sẽ nhận ngay 10 lon nước tăng lực Pepsi, với ưu đãi 'mua │
# │ 8 tặng 2'. Đây là cơ hội tuyệt vời để cả nhà mình dự trữ cho những ngày cần năng lượng cao. Đừng bỏ lỡ nhé!"    │
# │                                                                                                                 │
# │ ---                                                                                                             │
# │                                                                                                                 │
# │ ## **Kêu gọi mua hàng**:                                                                                        │
# │                                                                                                                 │
# │ "Vậy còn chần chừ gì nữa, các anh chị em ơi! Hãy nhanh tay đặt hàng ngay hôm nay để trải nghiệm sự khác biệt mà │
# │ Nước tăng lực Pepsi mang lại. Chỉ với 360k cho khay 10 lon, bạn không chỉ đang tiết kiệm mà còn đang đầu tư vào │
# │ sức khỏe và tinh thần của mình. Hãy click vào đường link ngay bên dưới để đặt hàng nhé!"                        │
# │                                                                                                                 │
# │ ---                                                                                                             │
# │                                                                                                                 │
# │ ## **Làm nổi bật ưu điểm bán hàng của sản phẩm**:                                                               │
# │                                                                                                                 │
# │ "Nước tăng lực Pepsi không chỉ giúp bạn tỉnh táo mà còn mang lại hương vị tươi mát, dễ uống. Đặc biệt, sản phẩm │
# │ này là lựa chọn lý tưởng cho những ai thường xuyên phải làm việc trong môi trường áp lực cao. Với Nước tăng lực │
# │ Pepsi, bạn có thể tự tin rằng mình luôn có đủ năng lượng để hoàn thành mọi nhiệm vụ. Không chỉ là một thức      │
# │ uống, đây là người đồng hành đắc lực giúp bạn vượt qua những thử thách hàng ngày."                              │
# │                                                                                                                 │
# │ ---                                                                                                             │
# │                                                                                                                 │
# │ ## **Gợi nhớ đặc điểm sản phẩm**:                                                                               │
# │                                                                                                                 │
# │ "Để giúp các anh chị em dễ dàng nhớ lại, em xin tóm tắt lại những đặc điểm nổi bật của Nước tăng lực Pepsi nhé! │
# │ Sản phẩm giúp tỉnh táo, tăng cường sự tập trung, và có hương vị thơm ngon, dễ uống. Mỗi lon Nước tăng lực Pepsi │
# │ sẽ là nguồn năng lượng tuyệt vời, giúp bạn luôn trong trạng thái sẵn sàng cho mọi thử thách."                   │
# │                                                                                                                 │
# │ ---                                                                                                             │
# │                                                                                                                 │
# │ ## **Kêu gọi mua hàng**:                                                                                        │
# │                                                                                                                 │
# │ "Nhớ nhé mọi người, chỉ với 360k cho khay 10 lon Nước tăng lực Pepsi trong phiên livestream này! Đây là cơ hội  │
# │ không thể bỏ qua, hãy đặt hàng ngay bây giờ để không bỏ lỡ ưu đãi đặc biệt này. Thời gian có hạn, hãy nhanh     │
# │ chân lên nhé!"                                                                                                  │
# │                                                                                                                 │
# │ ---                                                                                                             │
# │                                                                                                                 │
# │ ## **Sản phẩm dành cho ai và không dành cho ai**:                                                               │
# │                                                                                                                 │
# │ "Nước tăng lực Pepsi là lựa chọn hoàn hảo cho những ai cần một nguồn năng lượng nhanh chóng, phù hợp cho cả trẻ │
# │ em trên 1 tuổi cho đến người lớn. Tuy nhiên, em xin lưu ý rằng sản phẩm này không dành cho những ai nhạy cảm    │
# │ với caffeine hoặc có vấn đề sức khỏe liên quan đến tiêu thụ đồ uống có ga. Hãy cân nhắc trước khi sử dụng nhé!" │
# │                                                                                                                 │
# │ ---                                                                                                             │
# │                                                                                                                 │
# │ ## **Thúc đẩy người xem mua hàng**:                                                                             │
# │                                                                                                                 │
# │ "Cuối cùng, em muốn nhắn nhủ đến cả nhà rằng, Nước tăng lực Pepsi không chỉ mang lại sự tỉnh táo mà còn giúp    │
# │ bạn tự tin hơn trong công việc và cuộc sống. Hãy tưởng tượng cảm giác tuyệt vời khi bạn hoàn thành mọi việc một │
# │ cách dễ dàng và hiệu quả. Đừng chần chừ, hãy đặt hàng ngay hôm nay và trải nghiệm sự khác biệt nhé!"            │
# │                                                                                                                 │
# │ ---                                                                                                             │
# │                                                                                                                 │
# │ ## **Cam kết dịch vụ**:                                                                                         │
# │                                                                                                                 │
# │ "Em cũng muốn đảm bảo với mọi người rằng, khi đặt hàng Nước tăng lực Pepsi, bạn sẽ nhận được sự phục vụ tận     │
# │ tình và chu đáo từ đội ngũ của chúng em. Nếu có bất kỳ vấn đề nào liên quan đến sản phẩm, chúng em sẽ hỗ trợ    │
# │ bạn trong việc đổi trả và đảm bảo chất lượng sản phẩm. Hãy yên tâm và trải nghiệm nhé!"                         │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Enter your query:                                                                                               │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Hãy viết lại văn bản với văn phong vui vẻ
# ╭─────────────────────────────────────────────── Chatbot Response ────────────────────────────────────────────────╮
# │ ## **Tên sản phẩm**: Nước tăng lực Pepsi                                                                        │
# │                                                                                                                 │
# │ ---                                                                                                             │
# │                                                                                                                 │
# │ ## **Mở đầu sản phẩm hoặc chuyển tiếp sản phẩm khác**:                                                          │
# │                                                                                                                 │
# │ "Cả nhà ơi, hôm nay em muốn giới thiệu cho mọi người một sản phẩm vô cùng tuyệt vời mà chắc chắn sẽ làm bừng    │
# │ sáng cả ngày của chúng ta! Đó chính là Nước tăng lực Pepsi! Không chỉ là một món đồ uống thông thường, mà đây   │
# │ là bí quyết giúp chúng ta tràn đầy năng lượng và luôn tỉnh táo. Nghe có hấp dẫn không nào? Cùng em khám phá sản │
# │ phẩm này nhé!"                                                                                                  │
# │                                                                                                                 │
# │ ---                                                                                                             │
# │                                                                                                                 │
# │ ## **Giới thiệu sản phẩm**:                                                                                     │
# │                                                                                                                 │
# │ "Nước tăng lực Pepsi là một người bạn đồng hành tuyệt vời trong cuộc sống bận rộn của chúng ta. Sản phẩm này    │
# │ không chỉ đơn thuần là một thức uống mà còn là nguồn sức mạnh giúp mọi thành viên trong gia đình đều có thể     │
# │ thêm năng lượng để vượt qua mọi thử thách. Dù bạn là học sinh đang ôn thi hay nhân viên văn phòng cần thêm động │
# │ lực để hoàn thành công việc, Nước tăng lực Pepsi sẽ là người bạn lý tưởng!                                      │
# │                                                                                                                 │
# │ Hãy tưởng tượng nhé: bạn đang làm việc chăm chỉ, nhưng bỗng dưng cảm thấy mệt mỏi và không thể tập trung. Thế   │
# │ thì sao không thử ngay một lon Nước tăng lực Pepsi? Một chút vị chua ngọt, sảng khoái sẽ giúp bạn tỉnh táo ngay │
# │ lập tức! Và đừng quên, sản phẩm này hoàn toàn an toàn cho trẻ em từ 1 tuổi trở lên, nên cả gia đình mình đều có │
# │ thể thưởng thức!"                                                                                               │
# │                                                                                                                 │
# │ ---                                                                                                             │
# │                                                                                                                 │
# │ ## **Giữ chân người xem**:                                                                                      │
# │                                                                                                                 │
# │ "Các anh chị em ơi, có bao giờ mọi người cảm thấy mệt mỏi giữa giờ học hay giờ làm không? Em tin chắc rằng ai   │
# │ trong chúng ta cũng đã từng trải qua cảm giác đó rồi! Vậy thì, mọi người thường làm gì để lấy lại năng lượng    │
# │ trong những lúc ấy? Hãy chia sẻ với em trong chat nhé! Em rất hào hứng muốn nghe những bí quyết của cả nhà      │
# │ mình!"                                                                                                          │
# │                                                                                                                 │
# │ ---                                                                                                             │
# │                                                                                                                 │
# │ ## **Đặc điểm sản phẩm**:                                                                                       │
# │                                                                                                                 │
# │ "Nước tăng lực Pepsi có một vài điểm nổi bật khiến em phải thốt lên rằng: 'Thật tuyệt vời!' Đầu tiên, sản phẩm  │
# │ này giúp tăng cường sự tỉnh táo, khiến mọi người luôn trong trạng thái sẵn sàng cho mọi thử thách. Không chỉ là │
# │ một thức uống, mà còn là một 'vị cứu tinh' trong những lúc cần thiết!                                           │
# │                                                                                                                 │
# │ Hơn nữa, hương vị của Nước tăng lực Pepsi thơm ngon vô cùng, khiến mỗi lần uống đều trở thành một trải nghiệm   │
# │ thú vị. Bạn có thể mang theo bên mình để sử dụng trong nhiều hoàn cảnh khác nhau: khi lái xe đường dài, trong   │
# │ những buổi họp căng thẳng hay thậm chí trong những buổi tiệc tùng với bạn bè. Với Nước tăng lực Pepsi, bạn sẽ   │
# │ luôn cảm thấy tươi mới và đầy sức sống!"                                                                        │
# │                                                                                                                 │
# │ ---                                                                                                             │
# │                                                                                                                 │
# │ ## **Tính năng nổi bật**:                                                                                       │
# │                                                                                                                 │
# │ "Đừng quên tính năng nổi bật cực chất của Nước tăng lực Pepsi - đó chính là khả năng giúp bạn tỉnh táo nhanh    │
# │ chóng! Sản phẩm này đã được thiết kế để cung cấp năng lượng ngay lập tức, giúp bạn luôn trong trạng thái sẵn    │
# │ sàng cho mọi cuộc phiêu lưu. Hãy nghĩ đến những lúc bạn cần hoàn thành một công việc gấp gáp hoặc chuẩn bị cho  │
# │ một buổi thi quan trọng - một lon Nước tăng lực Pepsi sẽ là người bạn đồng hành tuyệt vời, giúp bạn vượt qua    │
# │ mọi rào cản với nụ cười trên môi!"                                                                              │
# │                                                                                                                 │
# │ ---                                                                                                             │
# │                                                                                                                 │
# │ ## **Giá niêm yết và giá giảm trong phiên live**:                                                               │
# │                                                                                                                 │
# │ "Nào, hãy cùng em xem qua mức giá của sản phẩm này nhé! Giá niêm yết cho Nước tăng lực Pepsi cực kỳ hợp lý: 45k │
# │ cho một lon đơn, 235k cho lốc 6 lon, và 450k cho khay 10 lon. Nhưng hôm nay, trong phiên livestream này, chúng  │
# │ ta có một deal cực kỳ hot: chỉ với 360k, bạn sẽ nhận ngay 10 lon nước tăng lực Pepsi với ưu đãi 'mua 8 tặng 2'. │
# │ Wow, đây là cơ hội tuyệt vời để cả nhà mình dự trữ cho những ngày cần năng lượng cao đấy! Nhanh tay lên nhé!"   │
# │                                                                                                                 │
# │ ---                                                                                                             │
# │                                                                                                                 │
# │ ## **Kêu gọi mua hàng**:                                                                                        │
# │                                                                                                                 │
# │ "Vậy còn chần chừ gì nữa, các anh chị em ơi! Hãy nhanh tay đặt hàng ngay hôm nay để trải nghiệm sự khác biệt mà │
# │ Nước tăng lực Pepsi mang lại. Chỉ với 360k cho khay 10 lon, bạn không chỉ tiết kiệm mà còn đang đầu tư vào sức  │
# │ khỏe và tinh thần của mình. Hãy click vào đường link ngay bên dưới để đặt hàng nhé! Đừng bỏ lỡ cơ hội này nha!" │
# │                                                                                                                 │
# │ ---                                                                                                             │
# │                                                                                                                 │
# │ ## **Làm nổi bật ưu điểm bán hàng của sản phẩm**:                                                               │
# │                                                                                                                 │
# │ "Nước tăng lực Pepsi không chỉ giúp bạn tỉnh táo mà còn mang lại hương vị tươi mát, dễ uống. Đây chính là lựa   │
# │ chọn lý tưởng cho những ai thường xuyên phải làm việc trong môi trường áp lực cao. Với Nước tăng lực Pepsi, bạn │
# │ có thể tự tin rằng mình luôn có đủ năng lượng để hoàn thành mọi nhiệm vụ. Hãy thử ngay và cảm nhận sự khác      │
# │ biệt!"                                                                                                          │
# │                                                                                                                 │
# │ ---                                                                                                             │
# │                                                                                                                 │
# │ ## **Gợi nhớ đặc điểm sản phẩm**:                                                                               │
# │                                                                                                                 │
# │ "Để giúp các anh chị em dễ dàng nhớ lại, em xin tóm tắt lại những đặc điểm nổi bật của Nước tăng lực Pepsi nhé! │
# │ Sản phẩm giúp tỉnh táo, tăng cường sự tập trung, và có hương vị thơm ngon, dễ uống. Mỗi lon Nước tăng lực Pepsi │
# │ sẽ là nguồn năng lượng tuyệt vời, giúp bạn luôn trong trạng thái sẵn sàng cho mọi thử thách."                   │
# │                                                                                                                 │
# │ ---                                                                                                             │
# │                                                                                                                 │
# │ ## **Kêu gọi mua hàng**:                                                                                        │
# │                                                                                                                 │
# │ "Nhớ nhé mọi người, chỉ với 360k cho khay 10 lon Nước tăng lực Pepsi trong phiên livestream này! Đây là cơ hội  │
# │ không thể bỏ qua, hãy đặt hàng ngay bây giờ để không bỏ lỡ ưu đãi đặc biệt này. Thời gian có hạn, hãy nhanh     │
# │ chân lên nhé!"                                                                                                  │
# │                                                                                                                 │
# │ ---                                                                                                             │
# │                                                                                                                 │
# │ ## **Sản phẩm dành cho ai và không dành cho ai**:                                                               │
# │                                                                                                                 │
# │ "Nước tăng lực Pepsi là lựa chọn hoàn hảo cho những ai cần một nguồn năng lượng nhanh chóng, phù hợp cho cả trẻ │
# │ em trên 1 tuổi cho đến người lớn. Tuy nhiên, em xin lưu ý rằng sản phẩm này không dành cho những ai nhạy cảm    │
# │ với caffeine hoặc có vấn đề sức khỏe liên quan đến tiêu thụ đồ uống có ga. Hãy cân nhắc trước khi sử dụng nhé!" │
# │                                                                                                                 │
# │ ---                                                                                                             │
# │                                                                                                                 │
# │ ## **Thúc đẩy người xem mua hàng**:                                                                             │
# │                                                                                                                 │
# │ "Cuối cùng, em muốn nhắn nhủ đến cả nhà rằng, Nước tăng lực Pepsi không chỉ mang lại sự tỉnh táo mà còn giúp    │
# │ bạn tự tin hơn trong công việc và cuộc sống. Hãy tưởng tượng cảm giác tuyệt vời khi bạn hoàn thành mọi việc một │
# │ cách dễ dàng và hiệu quả. Đừng chần chừ, hãy đặt hàng ngay hôm nay và trải nghiệm sự khác biệt nhé!"            │
# │                                                                                                                 │
# │ ---                                                                                                             │
# │                                                                                                                 │
# │ ## **Cam kết dịch vụ**:                                                                                         │
# │                                                                                                                 │
# │ "Em cũng muốn đảm bảo với mọi người rằng, khi đặt hàng Nước tăng lực Pepsi, bạn sẽ nhận được sự phục vụ tận     │
# │ tình và chu đáo từ đội ngũ của chúng em. Nếu có bất kỳ vấn đề nào liên quan đến sản phẩm, chúng em sẽ hỗ trợ    │
# │ bạn trong việc đổi trả và đảm bảo chất lượng sản phẩm. Hãy yên tâm và trải nghiệm nhé! Chúc cả nhà mình luôn    │
# │ tràn đầy năng lượng!"                                                                                           │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Enter your query:                                                                                               │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Hãy viết lại với mỗi đoạn 50 từ
# ╭─────────────────────────────────────────────── Chatbot Response ────────────────────────────────────────────────╮
# │ ## **Tên sản phẩm**: Nước tăng lực Pepsi                                                                        │
# │                                                                                                                 │
# │ ---                                                                                                             │
# │                                                                                                                 │
# │ ## **Mở đầu sản phẩm hoặc chuyển tiếp sản phẩm khác**:                                                          │
# │                                                                                                                 │
# │ "Cả nhà ơi, hôm nay em muốn giới thiệu cho mọi người một sản phẩm cực kỳ tuyệt vời giúp chúng ta tràn đầy năng  │
# │ lượng, đó chính là Nước tăng lực Pepsi! Cùng em khám phá bí quyết này nhé!"                                     │
# │                                                                                                                 │
# │ ---                                                                                                             │
# │                                                                                                                 │
# │ ## **Giới thiệu sản phẩm**:                                                                                     │
# │                                                                                                                 │
# │ "Nước tăng lực Pepsi không chỉ là một món đồ uống mà còn là nguồn sức mạnh giúp mọi thành viên trong gia đình   │
# │ tràn đầy năng lượng. Dù bạn học tập hay làm việc, sản phẩm này sẽ là người bạn lý tưởng để vượt qua mọi thử     │
# │ thách!"                                                                                                         │
# │                                                                                                                 │
# │ ---                                                                                                             │
# │                                                                                                                 │
# │ ## **Giữ chân người xem**:                                                                                      │
# │                                                                                                                 │
# │ "Các anh chị em ơi, có bao giờ cảm thấy mệt mỏi giữa giờ học hay giờ làm không? Hãy chia sẻ với em trong chat   │
# │ nhé! Em rất muốn biết mọi người thường làm gì để lấy lại năng lượng trong những lúc như vậy!"                   │
# │                                                                                                                 │
# │ ---                                                                                                             │
# │                                                                                                                 │
# │ ## **Đặc điểm sản phẩm**:                                                                                       │
# │                                                                                                                 │
# │ "Nước tăng lực Pepsi nổi bật với khả năng tăng cường sự tỉnh táo. Mỗi sip đều mang đến hương vị thơm ngon, giúp │
# │ bạn luôn cảm thấy sảng khoái. Sản phẩm này thật tiện lợi khi mang theo bên mình trong nhiều tình huống khác     │
# │ nhau!"                                                                                                          │
# │                                                                                                                 │
# │ ---                                                                                                             │
# │                                                                                                                 │
# │ ## **Tính năng nổi bật**:                                                                                       │
# │                                                                                                                 │
# │ "Tính năng nổi bật của Nước tăng lực Pepsi là giúp bạn tỉnh táo nhanh chóng. Sản phẩm này giúp bạn luôn trong   │
# │ trạng thái sẵn sàng cho mọi thử thách. Hãy nghĩ đến những lúc cần hoàn thành công việc gấp gáp – Pepsi sẽ là    │
# │ người bạn đồng hành tuyệt vời!"                                                                                 │
# │                                                                                                                 │
# │ ---                                                                                                             │
# │                                                                                                                 │
# │ ## **Giá niêm yết và giá giảm trong phiên live**:                                                               │
# │                                                                                                                 │
# │ "Giá niêm yết cho Nước tăng lực Pepsi là 45k cho một lon, 235k cho lốc 6 lon, và 450k cho khay 10 lon. Nhưng    │
# │ hôm nay, trong phiên livestream, bạn chỉ cần 360k cho khay 10 lon với ưu đãi 'mua 8 tặng 2'. Đừng bỏ lỡ nhé!"   │
# │                                                                                                                 │
# │ ---                                                                                                             │
# │                                                                                                                 │
# │ ## **Kêu gọi mua hàng**:                                                                                        │
# │                                                                                                                 │
# │ "Nào, còn chần chừ gì nữa, các anh chị em ơi! Hãy nhanh tay đặt hàng ngay hôm nay để trải nghiệm sự khác biệt   │
# │ mà Nước tăng lực Pepsi mang lại. Chỉ với 360k cho khay 10 lon, bạn đang đầu tư vào sức khỏe của mình đấy!"      │
# │                                                                                                                 │
# │ ---                                                                                                             │
# │                                                                                                                 │
# │ ## **Làm nổi bật ưu điểm bán hàng của sản phẩm**:                                                               │
# │                                                                                                                 │
# │ "Nước tăng lực Pepsi không chỉ giúp bạn tỉnh táo mà còn mang đến hương vị tươi mát, dễ uống. Đây chính là lựa   │
# │ chọn hoàn hảo cho những ai thường xuyên phải làm việc trong môi trường áp lực cao. Hãy thử ngay để cảm nhận sự  │
# │ khác biệt!"                                                                                                     │
# │                                                                                                                 │
# │ ---                                                                                                             │
# │                                                                                                                 │
# │ ## **Gợi nhớ đặc điểm sản phẩm**:                                                                               │
# │                                                                                                                 │
# │ "Để giúp mọi người nhớ lại, Nước tăng lực Pepsi giúp tỉnh táo, tăng cường sự tập trung và có hương vị thơm      │
# │ ngon. Mỗi lon là nguồn năng lượng tuyệt vời, giúp bạn luôn sẵn sàng cho mọi thử thách cuộc sống!"               │
# │                                                                                                                 │
# │ ---                                                                                                             │
# │                                                                                                                 │
# │ ## **Kêu gọi mua hàng**:                                                                                        │
# │                                                                                                                 │
# │ "Nhớ nhé mọi người, chỉ với 360k cho khay 10 lon Nước tăng lực Pepsi trong phiên livestream này! Đây là cơ hội  │
# │ không thể bỏ qua, hãy đặt hàng ngay bây giờ để không bỏ lỡ ưu đãi đặc biệt này nhé!"                            │
# │                                                                                                                 │
# │ ---                                                                                                             │
# │                                                                                                                 │
# │ ## **Sản phẩm dành cho ai và không dành cho ai**:                                                               │
# │                                                                                                                 │
# │ "Nước tăng lực Pepsi là lựa chọn tuyệt vời cho những ai cần năng lượng nhanh chóng, phù hợp cho trẻ em trên 1   │
# │ tuổi đến người lớn. Tuy nhiên, sản phẩm này không dành cho những ai nhạy cảm với caffeine. Hãy cân nhắc trước   │
# │ khi sử dụng nhé!"                                                                                               │
# │                                                                                                                 │
# │ ---                                                                                                             │
# │                                                                                                                 │
# │ ## **Thúc đẩy người xem mua hàng**:                                                                             │
# │                                                                                                                 │
# │ "Cuối cùng, Nước tăng lực Pepsi không chỉ mang lại sự tỉnh táo mà còn giúp bạn tự tin hơn trong công việc và    │
# │ cuộc sống. Hãy tưởng tượng cảm giác tuyệt vời khi bạn hoàn thành mọi việc dễ dàng. Đặt hàng ngay để trải nghiệm │
# │ nhé!"                                                                                                           │
# │                                                                                                                 │
# │ ---                                                                                                             │
# │                                                                                                                 │
# │ ## **Cam kết dịch vụ**:                                                                                         │
# │                                                                                                                 │
# │ "Khi đặt hàng Nước tăng lực Pepsi, bạn sẽ nhận được sự phục vụ tận tình từ đội ngũ của chúng em. Nếu có vấn đề  │
# │ nào liên quan đến sản phẩm, chúng em sẽ hỗ trợ bạn trong việc đổi trả và đảm bảo chất lượng. Hãy yên tâm và     │
# │ trải nghiệm nhé!"                                                                                               │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Enter your query:                                                                                               │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# FINISH
# ╭──────────────────────────────────╮
# │ Thank you for chatting! Goodbye. │
# ╰──────────────────────────────────╯

# %% [markdown]
# # END
